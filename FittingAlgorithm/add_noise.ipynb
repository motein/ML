# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)
X = np.linspace(0, 1000, 100)
Y = (2*X) + 2 + 20*np.random.randn(100)
data = np.hstack((X.reshape(100,1),Y.reshape(100,1)))
plt.plot(X, Y)
plt.show()

# %%
N=10000
Wafer1 = np.random.normal(loc = 0.0, scale = 1.0, size = N) + np.random.randn(N) * 0.1
Wafer2 = np.random.normal(loc = 2.0, scale = 1.0, size = N) + np.random.randn(N) * 0.1
print(np.min(Wafer1))

plt.hist(Wafer1,bins=30)
plt.hist(Wafer2,bins=30)
# Out:
# -3.6164140915398972
# (array([  2.,   1.,  12.,  15.,  34.,  56., 100., 138., 248., 334., 498.,
#         699., 839., 914., 969., 950., 912., 867., 678., 578., 408., 279.,
#         196., 136.,  68.,  38.,  15.,  13.,   2.,   1.]),
#  array([-1.7486895 , -1.5006336 , -1.25257771, -1.00452182, -0.75646593,
#         -0.50841003, -0.26035414, -0.01229825,  0.23575764,  0.48381354,
#          0.73186943,  0.97992532,  1.22798122,  1.47603711,  1.724093  ,
#          1.97214889,  2.22020479,  2.46826068,  2.71631657,  2.96437247,
#          3.21242836,  3.46048425,  3.70854014,  3.95659604,  4.20465193,
#          4.45270782,  4.70076371,  4.94881961,  5.1968755 ,  5.44493139,
#          5.69298729]),
#  <a list of 30 Patch objects>)
