# %%
import tensorflow as tf
import numpy as np
import gym
import time


#####################  hyper parameters  ####################

MAX_EPISODES = 200
MAX_EP_STEPS = 200
LR_A = 0.001    # learning rate for actor
LR_C = 0.002    # learning rate for critic
GAMMA = 0.9     # reward discount
TAU = 0.01      # soft replacement
MEMORY_CAPACITY = 10000
BATCH_SIZE = 32

RENDER = False
ENV_NAME = 'Pendulum-v0'

# %%
###############################  DDPG  ####################################


class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.memory = np.zeros((MEMORY_CAPACITY, s_dim * 2 + a_dim + 1), dtype=np.float32)
        self.pointer = 0
        self.sess = tf.Session()

        self.a_dim, self.s_dim, self.a_bound = a_dim, s_dim, a_bound,
        self.S = tf.placeholder(tf.float32, [None, s_dim], 's')
        self.S_ = tf.placeholder(tf.float32, [None, s_dim], 's_')
        self.R = tf.placeholder(tf.float32, [None, 1], 'r')

        self.a = self._build_a(self.S,)
        q = self._build_c(self.S, self.a, )
        a_params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='Actor')
        c_params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='Critic')
        ema = tf.train.ExponentialMovingAverage(decay=1 - TAU)          # soft replacement

        def ema_getter(getter, name, *args, **kwargs):
            return ema.average(getter(name, *args, **kwargs))

        target_update = [ema.apply(a_params), ema.apply(c_params)]      # soft update operation
        a_ = self._build_a(self.S_, reuse=True, custom_getter=ema_getter)   # replaced target parameters
        q_ = self._build_c(self.S_, a_, reuse=True, custom_getter=ema_getter)

        a_loss = - tf.reduce_mean(q)  # maximize the q
        self.atrain = tf.train.AdamOptimizer(LR_A).minimize(a_loss, var_list=a_params)

        with tf.control_dependencies(target_update):    # soft replacement happened at here
            q_target = self.R + GAMMA * q_
            td_error = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.ctrain = tf.train.AdamOptimizer(LR_C).minimize(td_error, var_list=c_params)

        self.sess.run(tf.global_variables_initializer())

    def choose_action(self, s):
        return self.sess.run(self.a, {self.S: s[np.newaxis, :]})[0]

    def learn(self):
        indices = np.random.choice(MEMORY_CAPACITY, size=BATCH_SIZE)
        bt = self.memory[indices, :]
        bs = bt[:, :self.s_dim]
        ba = bt[:, self.s_dim: self.s_dim + self.a_dim]
        br = bt[:, -self.s_dim - 1: -self.s_dim]
        bs_ = bt[:, -self.s_dim:]

        self.sess.run(self.atrain, {self.S: bs})
        self.sess.run(self.ctrain, {self.S: bs, self.a: ba, self.R: br, self.S_: bs_})

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % MEMORY_CAPACITY  # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1

    def _build_a(self, s, reuse=None, custom_getter=None):
        trainable = True if reuse is None else False
        with tf.variable_scope('Actor', reuse=reuse, custom_getter=custom_getter):
            net = tf.layers.dense(s, 30, activation=tf.nn.relu, name='l1', trainable=trainable)
            a = tf.layers.dense(net, self.a_dim, activation=tf.nn.tanh, name='a', trainable=trainable)
            return tf.multiply(a, self.a_bound, name='scaled_a')

    def _build_c(self, s, a, reuse=None, custom_getter=None):
        trainable = True if reuse is None else False
        with tf.variable_scope('Critic', reuse=reuse, custom_getter=custom_getter):
            n_l1 = 30
            w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable=trainable)
            w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable=trainable)
            b1 = tf.get_variable('b1', [1, n_l1], trainable=trainable)
            net = tf.nn.relu(tf.matmul(s, w1_s) + tf.matmul(a, w1_a) + b1)
            return tf.layers.dense(net, 1, trainable=trainable) # Q(s,a)

# %%
###############################  training  ####################################

env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(1)

s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
a_bound = env.action_space.high

ddpg = DDPG(a_dim, s_dim, a_bound)

var = 3  # control exploration
t1 = time.time()
for i in range(MAX_EPISODES):
    s = env.reset()
    ep_reward = 0
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render()

        # Add exploration noise
        a = ddpg.choose_action(s)
        a = np.clip(np.random.normal(a, var), -2, 2)    # add randomness to action selection for exploration
        s_, r, done, info = env.step(a)

        ddpg.store_transition(s, a, r / 10, s_)

        if ddpg.pointer > MEMORY_CAPACITY:
            var *= .9995    # decay the action randomness
            ddpg.learn()

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS-1:
            print('Episode:', i, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % var, )
            # if ep_reward > -300:RENDER = True
            break

print('Running time: ', time.time() - t1)
# Out:
# WARNING:tensorflow:From <ipython-input-2-b9825fe5debb>:61: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:667: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episode: 0  Reward: -1183 Explore: 3.00
# Episode: 1  Reward: -1121 Explore: 3.00
# Episode: 2  Reward: -1089 Explore: 3.00
# Episode: 3  Reward: -1156 Explore: 3.00
# Episode: 4  Reward: -1248 Explore: 3.00
# Episode: 5  Reward: -1100 Explore: 3.00
# Episode: 6  Reward: -1132 Explore: 3.00
# Episode: 7  Reward: -1238 Explore: 3.00
# Episode: 8  Reward: -1103 Explore: 3.00
# Episode: 9  Reward: -1032 Explore: 3.00
# Episode: 10  Reward: -1203 Explore: 3.00
# Episode: 11  Reward: -1145 Explore: 3.00
# Episode: 12  Reward: -1326 Explore: 3.00
# Episode: 13  Reward: -1159 Explore: 3.00
# Episode: 14  Reward: -1132 Explore: 3.00
# Episode: 15  Reward: -1230 Explore: 3.00
# Episode: 16  Reward: -1268 Explore: 3.00
# Episode: 17  Reward: -1302 Explore: 3.00
# Episode: 18  Reward: -1191 Explore: 3.00
# Episode: 19  Reward: -1215 Explore: 3.00
# Episode: 20  Reward: -1312 Explore: 3.00
# Episode: 21  Reward: -1164 Explore: 3.00
# Episode: 22  Reward: -1306 Explore: 3.00
# Episode: 23  Reward: -1307 Explore: 3.00
# Episode: 24  Reward: -1112 Explore: 3.00
# Episode: 25  Reward: -1162 Explore: 3.00
# Episode: 26  Reward: -999 Explore: 3.00
# Episode: 27  Reward: -1175 Explore: 3.00
# Episode: 28  Reward: -966 Explore: 3.00
# Episode: 29  Reward: -1355 Explore: 3.00
# Episode: 30  Reward: -1190 Explore: 3.00
# Episode: 31  Reward: -1257 Explore: 3.00
# Episode: 32  Reward: -1151 Explore: 3.00
# Episode: 33  Reward: -1051 Explore: 3.00
# Episode: 34  Reward: -1182 Explore: 3.00
# Episode: 35  Reward: -1031 Explore: 3.00
# Episode: 36  Reward: -1150 Explore: 3.00
# Episode: 37  Reward: -1276 Explore: 3.00
# Episode: 38  Reward: -1294 Explore: 3.00
# Episode: 39  Reward: -1309 Explore: 3.00
# Episode: 40  Reward: -1195 Explore: 3.00
# Episode: 41  Reward: -1325 Explore: 3.00
# Episode: 42  Reward: -1171 Explore: 3.00
# Episode: 43  Reward: -1174 Explore: 3.00
# Episode: 44  Reward: -1198 Explore: 3.00
# Episode: 45  Reward: -1261 Explore: 3.00
# Episode: 46  Reward: -1054 Explore: 3.00
# Episode: 47  Reward: -1121 Explore: 3.00
# Episode: 48  Reward: -1230 Explore: 3.00
# Episode: 49  Reward: -1120 Explore: 3.00
# Episode: 50  Reward: -983 Explore: 2.71
# Episode: 51  Reward: -1265 Explore: 2.46
# Episode: 52  Reward: -1682 Explore: 2.22
# Episode: 53  Reward: -1722 Explore: 2.01
# Episode: 54  Reward: -1764 Explore: 1.82
# Episode: 55  Reward: -1664 Explore: 1.65
# Episode: 56  Reward: -1652 Explore: 1.49
# Episode: 57  Reward: -1503 Explore: 1.35
# Episode: 58  Reward: -1311 Explore: 1.22
# Episode: 59  Reward: -1228 Explore: 1.10
# Episode: 60  Reward: -1365 Explore: 1.00
# Episode: 61  Reward: -1345 Explore: 0.90
# Episode: 62  Reward: -1471 Explore: 0.82
# Episode: 63  Reward: -1218 Explore: 0.74
# Episode: 64  Reward: -1343 Explore: 0.67
# Episode: 65  Reward: -1357 Explore: 0.61
# Episode: 66  Reward: -1261 Explore: 0.55
# Episode: 67  Reward: -1538 Explore: 0.50
# Episode: 68  Reward: -1557 Explore: 0.45
# Episode: 69  Reward: -1532 Explore: 0.41
# Episode: 70  Reward: -1079 Explore: 0.37
# Episode: 71  Reward: -1542 Explore: 0.33
# Episode: 72  Reward: -1125 Explore: 0.30
# Episode: 73  Reward: -1035 Explore: 0.27
# Episode: 74  Reward: -749 Explore: 0.25
# Episode: 75  Reward: -961 Explore: 0.22
# Episode: 76  Reward: -968 Explore: 0.20
# Episode: 77  Reward: -132 Explore: 0.18
# Episode: 78  Reward: -1273 Explore: 0.16
# Episode: 79  Reward: -392 Explore: 0.15
# Episode: 80  Reward: -699 Explore: 0.14
# Episode: 81  Reward: 0 Explore: 0.12
# Episode: 82  Reward: -266 Explore: 0.11
# Episode: 83  Reward: -359 Explore: 0.10
# Episode: 84  Reward: -129 Explore: 0.09
# Episode: 85  Reward: -125 Explore: 0.08
# Episode: 86  Reward: -136 Explore: 0.07
# Episode: 87  Reward: -125 Explore: 0.07
# Episode: 88  Reward: -134 Explore: 0.06
# Episode: 89  Reward: -130 Explore: 0.05
# Episode: 90  Reward: -262 Explore: 0.05
# Episode: 91  Reward: -130 Explore: 0.04
# Episode: 92  Reward: -132 Explore: 0.04
# Episode: 93  Reward: -131 Explore: 0.04
# Episode: 94  Reward: -2 Explore: 0.03
# Episode: 95  Reward: -127 Explore: 0.03
# Episode: 96  Reward: -131 Explore: 0.03
# Episode: 97  Reward: -129 Explore: 0.02
# Episode: 98  Reward: -1153 Explore: 0.02
# Episode: 99  Reward: -379 Explore: 0.02
# Episode: 100  Reward: -252 Explore: 0.02
# Episode: 101  Reward: -129 Explore: 0.02
# Episode: 102  Reward: -375 Explore: 0.01
# Episode: 103  Reward: -2 Explore: 0.01
# Episode: 104  Reward: -121 Explore: 0.01
# Episode: 105  Reward: 0 Explore: 0.01
# Episode: 106  Reward: -4 Explore: 0.01
# Episode: 107  Reward: -128 Explore: 0.01
# Episode: 108  Reward: -249 Explore: 0.01
# Episode: 109  Reward: -131 Explore: 0.01
