# %%
import tensorflow as tf
import numpy as np
import gym
import time


#####################  hyper parameters  ####################

MAX_EPISODES = 200
MAX_EP_STEPS = 200
LR_A = 0.001    # learning rate for actor
LR_C = 0.002    # learning rate for critic
GAMMA = 0.9     # reward discount
TAU = 0.01      # soft replacement
MEMORY_CAPACITY = 10000
BATCH_SIZE = 32

RENDER = False
ENV_NAME = 'Pendulum-v0'

# %%
###############################  DDPG  ####################################

class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.memory = np.zeros((MEMORY_CAPACITY, s_dim * 2 + a_dim + 1), dtype=np.float32)
        self.pointer = 0
        self.sess = tf.Session()

        self.a_dim, self.s_dim, self.a_bound = a_dim, s_dim, a_bound,
        self.S = tf.placeholder(tf.float32, [None, s_dim], 's')
        self.S_ = tf.placeholder(tf.float32, [None, s_dim], 's_')
        self.R = tf.placeholder(tf.float32, [None, 1], 'r')

        with tf.variable_scope('Actor'):
            self.a = self._build_a(self.S, scope='eval', trainable=True)
            a_ = self._build_a(self.S_, scope='target', trainable=False)
        with tf.variable_scope('Critic'):
            # assign self.a = a in memory when calculating q for td_error,
            # otherwise the self.a is from Actor when updating Actor
            q = self._build_c(self.S, self.a, scope='eval', trainable=True)
            q_ = self._build_c(self.S_, a_, scope='target', trainable=False)

        # networks parameters
        self.ae_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/eval')
        self.at_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/target')
        self.ce_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/eval')
        self.ct_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/target')

        # target net replacement
        self.soft_replace = [tf.assign(t, (1 - TAU) * t + TAU * e)
                             for t, e in zip(self.at_params + self.ct_params, self.ae_params + self.ce_params)]

        q_target = self.R + GAMMA * q_
        # in the feed_dic for the td_error, the self.a should change to actions in memory
        td_error = tf.losses.mean_squared_error(labels=q_target, predictions=q)
        self.ctrain = tf.train.AdamOptimizer(LR_C).minimize(td_error, var_list=self.ce_params)

        a_loss = - tf.reduce_mean(q)    # maximize the q
        self.atrain = tf.train.AdamOptimizer(LR_A).minimize(a_loss, var_list=self.ae_params)

        self.sess.run(tf.global_variables_initializer())

    def choose_action(self, s):
        return self.sess.run(self.a, {self.S: s[np.newaxis, :]})[0]

    def learn(self):
        # soft target replacement
        self.sess.run(self.soft_replace)

        indices = np.random.choice(MEMORY_CAPACITY, size=BATCH_SIZE)
        bt = self.memory[indices, :]
        bs = bt[:, :self.s_dim]
        ba = bt[:, self.s_dim: self.s_dim + self.a_dim]
        br = bt[:, -self.s_dim - 1: -self.s_dim]
        bs_ = bt[:, -self.s_dim:]

        self.sess.run(self.atrain, {self.S: bs})
        self.sess.run(self.ctrain, {self.S: bs, self.a: ba, self.R: br, self.S_: bs_})

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % MEMORY_CAPACITY  # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1

    def _build_a(self, s, scope, trainable):
        with tf.variable_scope(scope):
            net = tf.layers.dense(s, 30, activation=tf.nn.relu, name='l1', trainable=trainable)
            a = tf.layers.dense(net, self.a_dim, activation=tf.nn.tanh, name='a', trainable=trainable)
            return tf.multiply(a, self.a_bound, name='scaled_a')

    def _build_c(self, s, a, scope, trainable):
        with tf.variable_scope(scope):
            n_l1 = 30
            w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable=trainable)
            w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable=trainable)
            b1 = tf.get_variable('b1', [1, n_l1], trainable=trainable)
            net = tf.nn.relu(tf.matmul(s, w1_s) + tf.matmul(a, w1_a) + b1)
            return tf.layers.dense(net, 1, trainable=trainable)  # Q(s,a)

# %%
###############################  training  ####################################

env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(1)

s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
a_bound = env.action_space.high

ddpg = DDPG(a_dim, s_dim, a_bound)

var = 3  # control exploration
t1 = time.time()
for i in range(MAX_EPISODES):
    s = env.reset()
    ep_reward = 0
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render()

        # Add exploration noise
        a = ddpg.choose_action(s)
        a = np.clip(np.random.normal(a, var), -2, 2)    # add randomness to action selection for exploration
        s_, r, done, info = env.step(a)

        ddpg.store_transition(s, a, r / 10, s_)

        if ddpg.pointer > MEMORY_CAPACITY:
            var *= .9995    # decay the action randomness
            ddpg.learn()

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS-1:
            print('Episode:', i, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % var, )
            # if ep_reward > -300:RENDER = True
            break
print('Running time: ', time.time() - t1)
# Out:
# WARNING:tensorflow:From <ipython-input-2-42988180f571>:68: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:667: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episode: 0  Reward: -1156 Explore: 3.00
# Episode: 1  Reward: -1280 Explore: 3.00
# Episode: 2  Reward: -1296 Explore: 3.00
# Episode: 3  Reward: -1302 Explore: 3.00
# Episode: 4  Reward: -1325 Explore: 3.00
# Episode: 5  Reward: -1402 Explore: 3.00
# Episode: 6  Reward: -1183 Explore: 3.00
# Episode: 7  Reward: -1341 Explore: 3.00
# Episode: 8  Reward: -1213 Explore: 3.00
# Episode: 9  Reward: -1247 Explore: 3.00
# Episode: 10  Reward: -1329 Explore: 3.00
# Episode: 11  Reward: -1289 Explore: 3.00
# Episode: 12  Reward: -1513 Explore: 3.00
# Episode: 13  Reward: -1173 Explore: 3.00
# Episode: 14  Reward: -1207 Explore: 3.00
# Episode: 15  Reward: -1381 Explore: 3.00
# Episode: 16  Reward: -1272 Explore: 3.00
# Episode: 17  Reward: -1111 Explore: 3.00
# Episode: 18  Reward: -1145 Explore: 3.00
# Episode: 19  Reward: -1135 Explore: 3.00
# Episode: 20  Reward: -1262 Explore: 3.00
# Episode: 21  Reward: -1200 Explore: 3.00
# Episode: 22  Reward: -1327 Explore: 3.00
# Episode: 23  Reward: -1564 Explore: 3.00
# Episode: 24  Reward: -1189 Explore: 3.00
# Episode: 25  Reward: -1273 Explore: 3.00
# Episode: 26  Reward: -1362 Explore: 3.00
# Episode: 27  Reward: -1266 Explore: 3.00
# Episode: 28  Reward: -1335 Explore: 3.00
# Episode: 29  Reward: -1304 Explore: 3.00
# Episode: 30  Reward: -1339 Explore: 3.00
# Episode: 31  Reward: -1012 Explore: 3.00
# Episode: 32  Reward: -1280 Explore: 3.00
# Episode: 33  Reward: -1229 Explore: 3.00
# Episode: 34  Reward: -1095 Explore: 3.00
# Episode: 35  Reward: -1247 Explore: 3.00
# Episode: 36  Reward: -1151 Explore: 3.00
# Episode: 37  Reward: -1325 Explore: 3.00
# Episode: 38  Reward: -1176 Explore: 3.00
# Episode: 39  Reward: -1351 Explore: 3.00
# Episode: 40  Reward: -1368 Explore: 3.00
# Episode: 41  Reward: -1221 Explore: 3.00
# Episode: 42  Reward: -1334 Explore: 3.00
# Episode: 43  Reward: -1391 Explore: 3.00
# Episode: 44  Reward: -1210 Explore: 3.00
# Episode: 45  Reward: -1242 Explore: 3.00
# Episode: 46  Reward: -1190 Explore: 3.00
# Episode: 47  Reward: -1207 Explore: 3.00
# Episode: 48  Reward: -1340 Explore: 3.00
# Episode: 49  Reward: -1315 Explore: 3.00
# Episode: 50  Reward: -1194 Explore: 2.71
# Episode: 51  Reward: -1224 Explore: 2.46
# Episode: 52  Reward: -1243 Explore: 2.22
# Episode: 53  Reward: -1309 Explore: 2.01
# Episode: 54  Reward: -1488 Explore: 1.82
# Episode: 55  Reward: -1559 Explore: 1.65
# Episode: 56  Reward: -1700 Explore: 1.49
# Episode: 57  Reward: -1321 Explore: 1.35
# Episode: 58  Reward: -1029 Explore: 1.22
# Episode: 59  Reward: -1352 Explore: 1.10
# Episode: 60  Reward: -1282 Explore: 1.00
# Episode: 61  Reward: -1362 Explore: 0.90
# Episode: 62  Reward: -1110 Explore: 0.82
# Episode: 63  Reward: -665 Explore: 0.74
# Episode: 64  Reward: -905 Explore: 0.67
# Episode: 65  Reward: -939 Explore: 0.61
# Episode: 66  Reward: -918 Explore: 0.55
# Episode: 67  Reward: -1038 Explore: 0.50
# Episode: 68  Reward: -928 Explore: 0.45
# Episode: 69  Reward: -919 Explore: 0.41
# Episode: 70  Reward: -723 Explore: 0.37
# Episode: 71  Reward: -551 Explore: 0.33
# Episode: 72  Reward: -292 Explore: 0.30
# Episode: 73  Reward: -525 Explore: 0.27
# Episode: 74  Reward: -135 Explore: 0.25
# Episode: 75  Reward: -280 Explore: 0.22
# Episode: 76  Reward: -568 Explore: 0.20
# Episode: 77  Reward: -129 Explore: 0.18
# Episode: 78  Reward: -547 Explore: 0.16
# Episode: 79  Reward: -381 Explore: 0.15
# Episode: 80  Reward: -416 Explore: 0.14
# Episode: 81  Reward: -2 Explore: 0.12
# Episode: 82  Reward: -268 Explore: 0.11
# Episode: 83  Reward: -497 Explore: 0.10
# Episode: 84  Reward: -134 Explore: 0.09
# Episode: 85  Reward: -124 Explore: 0.08
# Episode: 86  Reward: -131 Explore: 0.07
# Episode: 87  Reward: -123 Explore: 0.07
# Episode: 88  Reward: -131 Explore: 0.06
# Episode: 89  Reward: -264 Explore: 0.05
# Episode: 90  Reward: -250 Explore: 0.05
# Episode: 91  Reward: -132 Explore: 0.04
# Episode: 92  Reward: -261 Explore: 0.04
# Episode: 93  Reward: -127 Explore: 0.04
# Episode: 94  Reward: -2 Explore: 0.03
# Episode: 95  Reward: -129 Explore: 0.03
# Episode: 96  Reward: -270 Explore: 0.03
# Episode: 97  Reward: -138 Explore: 0.02
# Episode: 98  Reward: -134 Explore: 0.02
# Episode: 99  Reward: -387 Explore: 0.02
# Episode: 100  Reward: -249 Explore: 0.02
# Episode: 101  Reward: -130 Explore: 0.02
# Episode: 102  Reward: -269 Explore: 0.01
# Episode: 103  Reward: -11 Explore: 0.01
# Episode: 104  Reward: -943 Explore: 0.01
# Episode: 105  Reward: -10 Explore: 0.01
# Episode: 106  Reward: -10 Explore: 0.01
# Episode: 107  Reward: -127 Explore: 0.01
# Episode: 108  Reward: -251 Explore: 0.01
# Episode: 109  Reward: -130 Explore: 0.01
# Episode: 110  Reward: -133 Explore: 0.01
# Episode: 111  Reward: -130 Explore: 0.01
# Episode: 112  Reward: -375 Explore: 0.01
# Episode: 113  Reward: -272 Explore: 0.00
# Episode: 114  Reward: -1 Explore: 0.00
# Episode: 115  Reward: -382 Explore: 0.00
# Episode: 116  Reward: -382 Explore: 0.00
# Episode: 117  Reward: -381 Explore: 0.00
# Episode: 118  Reward: 0 Explore: 0.00
# Episode: 119  Reward: -272 Explore: 0.00
# Episode: 120  Reward: -269 Explore: 0.00
# Episode: 121  Reward: -138 Explore: 0.00
# Episode: 122  Reward: -243 Explore: 0.00
# Episode: 123  Reward: 0 Explore: 0.00
# Episode: 124  Reward: -130 Explore: 0.00
# Episode: 125  Reward: -270 Explore: 0.00
# Episode: 126  Reward: -272 Explore: 0.00
# Episode: 127  Reward: -273 Explore: 0.00
# Episode: 128  Reward: -4 Explore: 0.00
# Episode: 129  Reward: -5 Explore: 0.00
# Episode: 130  Reward: -2 Explore: 0.00
# Episode: 131  Reward: -283 Explore: 0.00
# Episode: 132  Reward: -144 Explore: 0.00
# Episode: 133  Reward: -136 Explore: 0.00
# Episode: 134  Reward: -515 Explore: 0.00
# Episode: 135  Reward: -268 Explore: 0.00
# Episode: 136  Reward: -306 Explore: 0.00
# Episode: 137  Reward: -137 Explore: 0.00
# Episode: 138  Reward: -293 Explore: 0.00
# Episode: 139  Reward: -249 Explore: 0.00
# Episode: 140  Reward: -134 Explore: 0.00
# Episode: 141  Reward: -549 Explore: 0.00
# Episode: 142  Reward: -135 Explore: 0.00
# Episode: 143  Reward: -128 Explore: 0.00
# Episode: 144  Reward: -127 Explore: 0.00
# Episode: 145  Reward: -269 Explore: 0.00
# Episode: 146  Reward: -377 Explore: 0.00
# Episode: 147  Reward: -128 Explore: 0.00
# Episode: 148  Reward: -1373 Explore: 0.00
# Episode: 149  Reward: -129 Explore: 0.00
# Episode: 150  Reward: -141 Explore: 0.00
# Episode: 151  Reward: -381 Explore: 0.00
# Episode: 152  Reward: -301 Explore: 0.00
# Episode: 153  Reward: -3 Explore: 0.00
# Episode: 154  Reward: -373 Explore: 0.00
# Episode: 155  Reward: -132 Explore: 0.00
# Episode: 156  Reward: -397 Explore: 0.00
# Episode: 157  Reward: -651 Explore: 0.00
# Episode: 158  Reward: -142 Explore: 0.00
# Episode: 159  Reward: -1482 Explore: 0.00
# Episode: 160  Reward: -527 Explore: 0.00
# Episode: 161  Reward: -278 Explore: 0.00
# Episode: 162  Reward: -127 Explore: 0.00
# Episode: 163  Reward: -9 Explore: 0.00
# Episode: 164  Reward: -125 Explore: 0.00
# Episode: 165  Reward: -1043 Explore: 0.00
# Episode: 166  Reward: -628 Explore: 0.00
# Episode: 167  Reward: -518 Explore: 0.00
# Episode: 168  Reward: -499 Explore: 0.00
# Episode: 169  Reward: -134 Explore: 0.00
# Episode: 170  Reward: -269 Explore: 0.00
# Episode: 171  Reward: -300 Explore: 0.00
# Episode: 172  Reward: -130 Explore: 0.00
# Episode: 173  Reward: -133 Explore: 0.00
# Episode: 174  Reward: -128 Explore: 0.00
# Episode: 175  Reward: -257 Explore: 0.00
# Episode: 176  Reward: -139 Explore: 0.00
# Episode: 177  Reward: -269 Explore: 0.00
# Episode: 178  Reward: -138 Explore: 0.00
# Episode: 179  Reward: -135 Explore: 0.00
# Episode: 180  Reward: -133 Explore: 0.00
# Episode: 181  Reward: -279 Explore: 0.00
# Episode: 182  Reward: -132 Explore: 0.00
# Episode: 183  Reward: -129 Explore: 0.00
# Episode: 184  Reward: -249 Explore: 0.00
# Episode: 185  Reward: -136 Explore: 0.00
# Episode: 186  Reward: -129 Explore: 0.00
# Episode: 187  Reward: -136 Explore: 0.00
# Episode: 188  Reward: -135 Explore: 0.00
# Episode: 189  Reward: -134 Explore: 0.00
# Episode: 190  Reward: -278 Explore: 0.00
# Episode: 191  Reward: -364 Explore: 0.00
# Episode: 192  Reward: -139 Explore: 0.00
# Episode: 193  Reward: -16 Explore: 0.00
# Episode: 194  Reward: -382 Explore: 0.00
# Episode: 195  Reward: -272 Explore: 0.00
# Episode: 196  Reward: -131 Explore: 0.00
# Episode: 197  Reward: -7 Explore: 0.00
# Episode: 198  Reward: -127 Explore: 0.00
# Episode: 199  Reward: -387 Explore: 0.00
# Running time:  48.009557485580444
