# %%
import gym
from RL_brain import DeepQNetwork

env = gym.make('CartPole-v0')
env = env.unwrapped

print(env.action_space)
print(env.observation_space)
print(env.observation_space.high)
print(env.observation_space.low)
# Out:
# Discrete(2)
# Box(4,)
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]

# %%
RL = DeepQNetwork(n_actions=env.action_space.n,
                  n_features=env.observation_space.shape[0],
                  learning_rate=0.01, e_greedy=0.9,
                  replace_target_iter=100, memory_size=2000,
                  e_greedy_increment=0.001,)

total_steps = 0


for i_episode in range(100):

    observation = env.reset()
    ep_r = 0
    while True:
        env.render()

        action = RL.choose_action(observation)

        observation_, reward, done, info = env.step(action)

        # the smaller theta and closer to center the better
        x, x_dot, theta, theta_dot = observation_
        r1 = (env.x_threshold - abs(x))/env.x_threshold - 0.8
        r2 = (env.theta_threshold_radians - abs(theta))/env.theta_threshold_radians - 0.5
        reward = r1 + r2

        RL.store_transition(observation, action, reward, observation_)

        ep_r += reward
        if total_steps > 1000:
            RL.learn()

        if done:
            print('episode: ', i_episode,
                  'ep_r: ', round(ep_r, 2),
                  ' epsilon: ', round(RL.epsilon, 2))
            break

        observation = observation_
        total_steps += 1

RL.plot_cost()
# Out:
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# episode:  0 ep_r:  10.91  epsilon:  0
# episode:  1 ep_r:  3.86  epsilon:  0
# episode:  2 ep_r:  10.86  epsilon:  0
# episode:  3 ep_r:  5.48  epsilon:  0
# episode:  4 ep_r:  3.49  epsilon:  0
# episode:  5 ep_r:  2.73  epsilon:  0
# episode:  6 ep_r:  8.43  epsilon:  0
# episode:  7 ep_r:  17.69  epsilon:  0
# episode:  8 ep_r:  6.61  epsilon:  0
# episode:  9 ep_r:  6.17  epsilon:  0
# episode:  10 ep_r:  2.75  epsilon:  0
# episode:  11 ep_r:  14.41  epsilon:  0
# episode:  12 ep_r:  13.25  epsilon:  0
# episode:  13 ep_r:  8.47  epsilon:  0
# episode:  14 ep_r:  9.7  epsilon:  0
# episode:  15 ep_r:  14.13  epsilon:  0
# episode:  16 ep_r:  11.9  epsilon:  0
# episode:  17 ep_r:  6.96  epsilon:  0
# episode:  18 ep_r:  4.7  epsilon:  0
# episode:  19 ep_r:  4.23  epsilon:  0
# episode:  20 ep_r:  7.99  epsilon:  0
# episode:  21 ep_r:  4.88  epsilon:  0
# episode:  22 ep_r:  9.49  epsilon:  0
# episode:  23 ep_r:  13.5  epsilon:  0
# episode:  24 ep_r:  1.91  epsilon:  0
# episode:  25 ep_r:  0.33  epsilon:  0
# episode:  26 ep_r:  1.05  epsilon:  0
# episode:  27 ep_r:  3.15  epsilon:  0
# episode:  28 ep_r:  1.47  epsilon:  0
# episode:  29 ep_r:  2.31  epsilon:  0
# episode:  30 ep_r:  3.04  epsilon:  0
# episode:  31 ep_r:  2.02  epsilon:  0
# episode:  32 ep_r:  6.03  epsilon:  0
# episode:  33 ep_r:  4.09  epsilon:  0
# episode:  34 ep_r:  7.53  epsilon:  0
# episode:  35 ep_r:  16.78  epsilon:  0
# episode:  36 ep_r:  8.73  epsilon:  0
# episode:  37 ep_r:  12.25  epsilon:  0
# episode:  38 ep_r:  3.64  epsilon:  0
# episode:  39 ep_r:  2.54  epsilon:  0
# episode:  40 ep_r:  11.71  epsilon:  0
# episode:  41 ep_r:  4.22  epsilon:  0
# episode:  42 ep_r:  9.86  epsilon:  0
# episode:  43 ep_r:  3.19  epsilon:  0
#
# target_params_replaced
#
# episode:  44 ep_r:  5.02  epsilon:  0.01
# episode:  45 ep_r:  4.73  epsilon:  0.02
# episode:  46 ep_r:  22.73  epsilon:  0.07
# episode:  47 ep_r:  4.52  epsilon:  0.09
#
# target_params_replaced
#
# episode:  48 ep_r:  7.45  epsilon:  0.11
# episode:  49 ep_r:  6.62  epsilon:  0.12
# episode:  50 ep_r:  14.79  epsilon:  0.16
# episode:  51 ep_r:  2.74  epsilon:  0.17
# episode:  52 ep_r:  4.0  epsilon:  0.19
#
# target_params_replaced
#
# episode:  53 ep_r:  14.11  epsilon:  0.22
# episode:  54 ep_r:  13.42  epsilon:  0.26
# episode:  55 ep_r:  3.86  epsilon:  0.28
#
# target_params_replaced
#
# episode:  56 ep_r:  5.26  epsilon:  0.32
# episode:  57 ep_r:  12.38  epsilon:  0.36
# episode:  58 ep_r:  3.36  epsilon:  0.38
# episode:  59 ep_r:  2.8  epsilon:  0.4
#
# target_params_replaced
#
# episode:  60 ep_r:  28.14  epsilon:  0.46
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  61 ep_r:  41.05  epsilon:  0.66
#
# target_params_replaced
#
# episode:  62 ep_r:  32.94  epsilon:  0.76
#
# target_params_replaced
#
# episode:  63 ep_r:  27.27  epsilon:  0.84
#
# target_params_replaced
#
# episode:  64 ep_r:  65.41  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  65 ep_r:  68.64  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  66 ep_r:  40.31  epsilon:  0.9
#
# target_params_replaced
#
# episode:  67 ep_r:  59.9  epsilon:  0.9
#
# target_params_replaced
#
# episode:  68 ep_r:  35.74  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  69 ep_r:  80.88  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  70 ep_r:  123.04  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  71 ep_r:  64.51  epsilon:  0.9
#
# target_params_replaced
#
# episode:  72 ep_r:  20.81  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  73 ep_r:  91.24  epsilon:  0.9
#
# target_params_replaced
#
# episode:  74 ep_r:  28.12  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  75 ep_r:  49.19  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  76 ep_r:  130.03  epsilon:  0.9
#
# target_params_replaced
#
# episode:  77 ep_r:  32.61  epsilon:  0.9
#
# target_params_replaced
#
#
# target_params_replaced
#
# episode:  78 ep_r:  66.53  epsilon:  0.9
#
# target_params_replaced
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-112e34a9eee3> in <module>
#      13     ep_r = 0
#      14     while True:
# ---> 15         env.render()
#      16
#      17         action = RL.choose_action(observation)
#
# c:\python36\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     186         self.poletrans.set_rotation(-x[2])
#     187
# --> 188         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     189
#     190     def close(self):
#
# c:\python36\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#     112             arr = arr.reshape(buffer.height, buffer.width, 4)
#     113             arr = arr[::-1,:,0:3]
# --> 114         self.window.flip()
#     115         self.onetime_geoms = []
#     116         return arr if return_rgb_array else self.isopen
#
# c:\python36\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     319     def flip(self):
#     320         self.draw_mouse_cursor()
# --> 321         self.context.flip()
#     322
#     323     def set_location(self, x, y):
#
# c:\python36\lib\site-packages\pyglet\gl\win32.py in flip(self)
#     224
#     225     def flip(self):
# --> 226         _gdi32.SwapBuffers(self.canvas.hdc)
#     227
#     228     def get_vsync(self):
#
# KeyboardInterrupt:
